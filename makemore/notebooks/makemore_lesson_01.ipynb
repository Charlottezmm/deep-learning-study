# %% [markdown]
# # Makemore Lesson 01
#
# Notes and code while following Andrej Karpathy's makemore lesson.
#
# ## Session Goals
#
# - Build a character-level bigram model.
# - Understand the names dataset, vocabulary, counts, probabilities, and loss.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Bigram Model
